# %%
import pandas as pd
import pickle

from utils import lang_dict

# %%
with open("/netscratch/fonseca/oscar-pre-processing/results/adult_pp_dict.pkl", 'rb') as file:
    dict_full = pickle.load(file)

# %%
lg_dict = {v:k for k,v in lang_dict.items()}

dict_full_2 = {lg_dict[k] : v for k,v in dict_full.items()}

with open("/netscratch/fonseca/oscar-pre-processing/results/adult_pp_dict.pkl", 'wb') as file:
    pickle.dump(dict_full_2,file)

# %%
dict_full_2
# Out:
# {'Slovak': 11482.729111494735,
#  'Esperanto': 481.74368,
#  'Kazakh': 754.0764786440678,
#  'Occitan': 95.58478550000001,
#  'English': 1321.848530311227,
#  'Thai': 45079.23397320559,
#  'German': 3865.0844278517334,
#  'Ukrainian': 8227.112214112714,
#  'Romanian': 3289.5020744583003,
#  'Tajik': 770.0148167647058,
#  'Urdu': 1318.9733090100167,
#  'Filipino': 2301.423049966292,
#  'Greek': 9700.148223445325,
#  'Turkish': 24512.005788401213,
#  'Azerbaijani': 4812.07932478012,
#  'Swedish': 6507.748918533279,
#  'Nepali': 6592.15979011639,
#  'Serbian': 4336.890046521912,
#  'Russian': 20473.30398881554,
#  'Bulgarian': 6477.285412765637,
#  'Japanese': 340410.97722689953,
#  'Czech': 18454.28785890177,
#  'Chinese': 148610.43757634936,
#  'Estonian': 5254.884522946542,
#  'Hungarian': 13742.707306890257,
#  'Lao': 1853.4081568627453,
#  'Uzbek': 63.486490116666666,
#  'Belarusian': 1275.9843824848485,
#  'Indonesian': 3318.0723786321005,
#  'Vietnamese': 1374.242075090026,
# ...

# %% [markdown]
# # Filter
# - Category
# - Quality Warnings
# - Min preplexity value: Universal Dependencies mean perplexity

# %%
df2 = pd.read_csv("./results/cat_qw_adult_pp_filters.csv")
df2['percentage_kept'] = round(df2['percentage_kept']*100,2)
df2
# Out:
#       language  percentage_kept
# 0       Polish             4.80
# 1        Czech             2.88
# 2    Hungarian             8.23
# 3      Finnish            10.56
# 4       Danish             2.05
# 5       German             6.48
# 6      Italian             2.13
# 7      Spanish             1.26
# 8        Greek             1.43
# 9   Lithuanian             7.17
# 10     Swedish             2.52
# 11    Romanian             7.13
# 12   Slovenian            10.24
# 13      French             4.14
# 14   Bulgarian             3.80
# 15      Slovak             6.04
# 16  Portuguese             3.69
# 17     English             4.86
# 18       Dutch             7.69
# 19    Estonian             6.63
# 20     Latvian            11.29

# %% [markdown]
# # Filter
# - Category
# - Quality Warnings
# - Min preplexity value: Universal Dependencies mean perplexity

# %% [markdown]
# # Filter
# - Category
# - Quality Warnings
# - Min preplexity value: Universal Dependencies mean perplexity

# %%
df3 = pd.read_csv("./results/cat_qw_UDpp_filters.csv")
df3['percentage_kept'] = round(df3['percentage_kept']*100,2)
df3
# Out:
#       language  percentage_kept
# 0    Slovenian             0.70
# 1        Greek             3.56
# 2      Spanish             1.85
# 3      Latvian             0.55
# 4     Estonian             1.35
# 5       Danish             1.42
# 6      English             1.77
# 7      Italian             3.29
# 8       French             2.47
# 9   Portuguese             1.16
# 10       Czech             1.36
# 11   Hungarian             5.27
# 12    Romanian             1.67
# 13  Lithuanian             1.34
# 14     Finnish             1.01
# 15      German             1.72
# 16      Polish             1.67
# 17      Slovak             0.60
# 18   Bulgarian             2.51
# 19       Dutch             0.53
# 20     Swedish             1.45

# %%
# Out:
#       language  percentage_kept
# 0    Slovenian             0.70
# 1        Greek             3.56
# 2      Spanish             1.85
# 3      Latvian             0.55
# 4     Estonian             1.35
# 5       Danish             1.42
# 6      English             1.77
# 7      Italian             3.29
# 8       French             2.47
# 9   Portuguese             1.16
# 10       Czech             1.36
# 11   Hungarian             5.27
# 12    Romanian             1.67
# 13  Lithuanian             1.34
# 14     Finnish             1.01
# 15      German             1.72
# 16      Polish             1.67
# 17      Slovak             0.60
# 18   Bulgarian             2.51
# 19       Dutch             0.53
# 20     Swedish             1.45

# %%
pp_dict_path = "/netscratch/fonseca/oscar-pre-processing/results/adult_pp_dict.pkl"


pp_dict_path.split('/')[-1]
# Out:
# 'adult_pp_dict.pkl'

# %%
import pickle

with open("/netscratch/fonseca/oscar-pre-processing/results/pp_score_adult_oscar_filt_minus_std15.pkl", 'rb') as file:
    dict_full = pickle.load(file)
print(dict_full)
# Out:
# {'Slovak': 9584.422869454014, 'English': 905.4588324129327, 'German': 3173.8120283605017, 'Romanian': 2530.3445169067686, 'Greek': 6110.026796272409, 'Swedish': 3437.242227941527, 'Bulgarian': 5257.190155432402, 'Czech': 16409.245274633886, 'Estonian': 5242.331094745565, 'Hungarian': 11918.694262410785, 'Polish': 7132.818396785782, 'Danish': 3003.1821188242902, 'Portuguese': 1947.1447415249845, 'Finnish': 8248.40717355475, 'Latvian': 2740.7469225806753, 'Slovenian': 1791.7273989166667, 'French': 1276.7750243387038, 'Irish': nan, 'Lithuanian': 26165.883171895457, 'Dutch': 1445.5865516427948, 'Italian': 3416.036249181336, 'Spanish': 1703.3987573582488, 'Croatian': nan, 'Maltese': nan}

# %%
import pickle

with open("/netscratch/fonseca/oscar-pre-processing/results/pp_score_adult_oscar_filt_minus_top5p.pkl", 'rb') as file:
    dict_ = pickle.load(file)
print(dict_)
# Out:
# {'Slovak': 9584.422869454014, 'English': 485.246289300029, 'German': 2496.4154827256043, 'Romanian': 2469.0164219171093, 'Greek': 7307.848865607105, 'Swedish': 3916.2879360414286, 'Bulgarian': 5192.975014778551, 'Czech': 15679.64786849974, 'Estonian': 2482.620339319266, 'Hungarian': 11648.51418365785, 'Polish': 7109.802557619198, 'Danish': 3066.680458809082, 'Portuguese': 1403.9798346011412, 'Finnish': 8758.925713804587, 'Latvian': 3455.87998539841, 'Slovenian': 1758.949966651316, 'French': 889.9854067555075, 'Irish': nan, 'Lithuanian': 28416.432920820735, 'Dutch': 1212.2278349819828, 'Italian': 2656.1988049642973, 'Spanish': 1336.190121759456, 'Croatian': nan, 'Maltese': nan}

# %%
assert None == float
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /netscratch/fonseca/oscar-pre-processing/notebooks/drafts.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://192.168.33.195:55212/netscratch/fonseca/oscar-pre-processing/notebooks/drafts.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> assert None == float
#
# AssertionError:
